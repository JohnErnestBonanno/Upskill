# %%
tests = ['alvin',
        'jason',
        'how now brown cow']

# %%
def greet(s):
    greeting = "hey " + str(s)
    return print(greeting)

# %%
for test in tests:
    greet(test)
# Out:
# hey alvin
# hey jason
# hey how now brown cow
